# %% [markdown]
# # Mars: solar occultation measurement
#
# In this example, we show how archNEMESIS can be used to calculate forward models for solar occultation. In particular, we are going to model the spectral signatures of different isotopes of CO (i.e., $^{12}$C$^{16}$O, $^{13}$C$^{16}$O and $^{12}$C$^{18}$O) in the atmosphere of Mars between 4170-4190 cm$^{-1}$ as observed by a high-resolution spectrometer (i.e., FWHM = 0.16 cm$^{-1}$).
#
# First of all, we show how all the input files can be read at once, and summarise the content of these files. Then, we will show how the forward models can be easily computed in python.

# %%
import archnemesis as ans
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
import sys,os
curr = os.getcwd()

# %% [markdown]
# ## 1. Input files
#
# archNEMESIS includes the master *Retrieval* class, which includes methods to easily read all NEMESIS inputs files and store the information in the reference classes. Depending on whether the input files are in the archNEMESIS HDF5 format or NEMESIS legacy format, one may use one of the *from_hdf5* or *from_legacy* methods to read these.
#
# Here, we are going to read the input files and explore some of the most important characteristics of this particular forward model.

# %%
#Name of the NEMESIS run
runname = 'mars_SO'

#Reading the information from the NEMESIS legacy files ans storing them into the Master class
NEMESIS = ans.Retrieval.from_legacy(runname,lazy_load=False)

#Specifying we are working with solar occultations
NEMESIS.nemesisSO = True
# Out:
# INFO :: load :: Retrieval.py-384 :: Loading ArchNemesis data for Retrieval(working_directory=/home/alday/Documents/Projects/archnemesis-dist/docs/examples/mars_solocc, runname=mars_SO, filetype=2)
# INFO :: read_input_files :: Files.py-441 :: Reading atmospheric files...
# INFO :: read_input_files :: Files.py-584 :: Reading .apr file
# INFO :: read_apr :: Variables_0.py-823 ::
# Variables_0 :: read_apr :: varident [5 2 2]. Constructed model "Model2" (id=2)
# INFO :: read_apr :: Variables_0.py-826 ::   Model2:
#   |- id : 2
#   |- parent classes: PreRTModelBase
#   |- description: In this model, the atmospheric parameters are scaled using a
#   |               single factor with  respect to the vertical profiles in the
#   |               reference atmosphere
#   |- n_state_vector_entries : 1
#   |- state_vector_slice : slice(0, 1, None)
#   |- state_vector_start : 0
#   |- target : 0
#   |- Parameters:
#   |  |- scaling_factor :
#   |  |  |- slice : slice(0, 1, None)
# ...

# %% [markdown]
# ### Atmosphere
#
# The profiles in this example were extracted from the Mars Climate Database v5.3 (Forget et al., 1999) using the climatological scenario, calculated at a latitude and longitude of 20$^\circ$N and 0$^\circ$E, at a local time of 8h (AM) and a solar longitude of 270$^\circ$ (i.e., summer solstice in the southern hemisphere).
#
# The abundance of CO predicted by the model was split into three different isotopes using the same isotopic fractionation as on Earth (i.e., $^{12}$C$^{16}$O = 98.65%; $^{13}$C$^{16}$O = 1.11%; $^{12}$C$^{18}$O = 0.19%).
#
# We do not include any aerosol profiles in the atmosphere for this particular example.

# %%
NEMESIS.Atmosphere.plot_Atm()

# %% [markdown]
# ### Measurement
#
# In this example, as we only want to model the spectrum, the information about the measured spectra is not relevant. However, the *.spx* file also defines the geometry of the observations and the spectral range and resolution to use.
#
# The spectral range in this example goes from 4170-4190 cm$^{-1}$, using a Gaussian instrument function with a FWHM of 0.16 cm$^{-1}$. The spectra is modelled at different tangent heights, ranging from 0-28 km with a vertical sampling of 2 km.

# %%
NEMESIS.Measurement.summary_info()
# Out:
# INFO :: summary_info :: Measurement_0.py-415 :: Spectral resolution of the measurement (FWHM) ::  0.16
# INFO :: summary_info :: Measurement_0.py-432 :: Field-of-view centered at ::  ('Latitude', 20.0, '- Longitude', 0.0)
# INFO :: summary_info :: Measurement_0.py-433 :: There are  (15, 'geometries in the measurement vector')
# INFO :: summary_info :: Measurement_0.py-435 ::
# INFO :: summary_info :: Measurement_0.py-436 :: GEOMETRY 1
# INFO :: summary_info :: Measurement_0.py-437 :: Minimum wavelength/wavenumber :: 2.3980815347721824 um/4170.0 cm^-1 - Maximum wavelength/wavenumber :: 2.386634844868735 um/4190.0 cm^-1
# INFO :: summary_info :: Measurement_0.py-466 :: Limb-viewing or solar occultation measurement. Latitude ::  (np.float64(20.0), ' - Longitude :: ', np.float64(0.0), ' - Tangent height :: ', np.float64(0.0))
# INFO :: summary_info :: Measurement_0.py-435 ::
# INFO :: summary_info :: Measurement_0.py-436 :: GEOMETRY 2
# ...

# %% [markdown]
# ### Variables
#
# In this example, we choose a parameterisation that allows us to easily change the isotopic ratios in the atmosphere. In particular, we choose the model parameterisation #2, which allows the scaling of an atmospheric profile and apply it to the minor isotopologues of CO, so that the scaling factors represent the isotopic ratios with respect to the Earth-like fractionation.

# %%
print('VARIDENT')
print(NEMESIS.Variables.VARIDENT)
print('')

print('Isotopic ratios with respect to Earth')
print(NEMESIS.Variables.XA)
print('')
# Out:
# VARIDENT
# [[5 2 2]
#  [5 3 2]]
#
# Isotopic ratios with respect to Earth
# [0.9  0.95]

# %% [markdown]
# ### CIA
#
# Given the low pressure of the atmosphere of Mars, Collision-Induced Absorption (CIA) is not relevant and is therefore not required. archNEMESIS will look for the *.cia* file, and if it is not present, it will not use CIA for the radiative transfer calculations, leaving this reference class empty.

# %%
print(NEMESIS.CIA)
# Out:
# None

# %% [markdown]
# ### Spectroscopy
#
# In this example, we do not include the high-resolution tables in the current working directory because of storage requirements, although these are available upon request.
#
# Here, we include only the three isotopologues of CO to contribute to the measured spectrum, as the absorption of all other gases in the atmosphere of Mars in this spectral range is negligible.

# %%
NEMESIS.Spectroscopy.summary_info()
# Out:
# INFO :: summary_info :: Spectroscopy_0.py-455 ::
# #===== SUMMARY =====#
# 	Spectroscopy_0 instance at memory location 129092262918352
# 	Calculation type ILBL ::  (<SpectralCalculationModeEnum.LINE_BY_LINE_TABLES: 2>, ' (line-by-line)')
# 	Number of radiatively-active gaseous species ::  3
# 	Gaseous species ::  ['CO (1)', 'CO (2)', 'CO (3)']
# 	Number of spectral points ::  22001
# 	Wavelength range ::  (np.float64(4169.0), '-', np.float64(4191.0))
# 	Step size ::  0.0010000000002037268
# 	Number of temperature levels ::  15
# 	Temperature range ::  (np.float32(150.0), '-', np.float32(220.0))
# 	Number of pressure levels ::  15
# 	Pressure range ::  (np.float32(1.5229979e-08), '-', np.float32(0.13533528))
# #===================#

# %% [markdown]
# ### Layering
#
# In this case, we specify the base altitude of the layers based on the tangent heights of our spectra. The base altitudes are specified in the Layer class.

# %%
NEMESIS.Layer.summary_info()
# Out:
# INFO :: summary_info :: Layer_0.py-252 :: Number of layers ::  35
# INFO :: summary_info :: Layer_0.py-265 :: Layers calculated by specified base altitudes
# INFO :: summary_info :: Layer_0.py-270 :: Layer properties calculated through mass weighted averages

# %% [markdown]
# ## 2. Running a foward model
#
# The easiest way to perform a forward model with archNEMESIS is to use the *run_forward_model()* method. This method will calculate the forward model for our specific case and will give back the modelled spectra, which will have the same array size as the measured spectrum in Measurement.MEAS.
#
# It must be noted that, since we turned on the *nemesisSO* flag, the forward model version to be used is the one optimised for solar occultation observations. In other cases, one may do the same by selecting the other retrieval versions (e.g., NEMESIS.nemesisdisc = True).

# %%
SPECONV = NEMESIS.run_forward_model()
# Out:
# INFO :: read_tables :: Spectroscopy_0.py-1461 :: Reading tables
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso1.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso2.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso3.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# INFO :: nemesisSOfm :: ForwardModel_0.py-916 :: Calculating forward model for solar occultation observation
# INFO :: read_tables :: Spectroscopy_0.py-1461 :: Reading tables
# ...

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3,1,figsize=(10,9))

#First geometry
igeom1 = NEMESIS.Measurement.NGEOM-5
ax1.fill_between(NEMESIS.Measurement.VCONV[:,igeom1],SPECONV[:,igeom1],np.ones(NEMESIS.Measurement.NCONV[igeom1]),alpha=0.5)
ax1.plot(NEMESIS.Measurement.VCONV[:,igeom1],SPECONV[:,igeom1])
ax1.set_facecolor('lightgray')
ax1.grid()
ax1.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom1,0])+' km')
ax1.set_ylabel('Transmission')

#Second geometry
igeom2 = 5
ax2.fill_between(NEMESIS.Measurement.VCONV[:,igeom2],SPECONV[:,igeom2],np.ones(NEMESIS.Measurement.NCONV[igeom2]),alpha=0.5)
ax2.plot(NEMESIS.Measurement.VCONV[:,igeom2],SPECONV[:,igeom2])
ax2.set_facecolor('lightgray')
ax2.grid()
ax2.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom2,0])+' km')
ax2.set_ylabel('Transmission')


#Third geometry
igeom3 = 2
ax3.fill_between(NEMESIS.Measurement.VCONV[:,igeom3],SPECONV[:,igeom3],np.ones(NEMESIS.Measurement.NCONV[igeom3]),alpha=0.5)
ax3.plot(NEMESIS.Measurement.VCONV[:,igeom3],SPECONV[:,igeom3])
ax3.set_facecolor('lightgray')
ax3.grid()
ax3.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom3,0])+' km')
ax3.set_ylabel('Transmission')
ax3.set_xlabel('Wavenumber (cm$^{-1}$)')

plt.tight_layout()

# %% [markdown]
# ## 3. Calculating the jacobian matrix
#
# Similarly, apart from the forward model, archNEMESIS allows the calculation of the jacobian matrix, which includes information about the sensitivity of the spectrum to each of the parameters in the state vector.
#
# This can be easily performed using the *run_jacobian_matrix()* method. As with the forward model, since we turned on the *nemesisSO* flag, the retrievals will be performed using this version of the forward model.
#
# The output of this function is the measurement vector (i.e., concatenation of all the transmission spectra at the different tangent heights), and the jacobian matrix (i.e., derivative of the transmission spectra with respect to the elements of the state vector, which represent the isotopic ratios).

# %%
YN,KK = NEMESIS.run_jacobian_matrix()
# Out:
# WARNING :: run_jacobian_matrix :: Retrieval.py-1318 :: Retrieval(runname=mars_SO) already has a modelled spectra, running the forward model will overwrite the current value
# INFO :: jacobian_nemesis :: ForwardModel_0.py-2272 :: Calculating analytical part of the Jacobian :: Calling nemesisfmg
# INFO :: nemesisSOfmg :: ForwardModel_0.py-1163 :: Calculating forward model for solar occultation observation
# INFO :: read_tables :: Spectroscopy_0.py-1461 :: Reading tables
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso1.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso2.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# ...

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(10,6))

ax1.plot(range(len(YN)),YN)
ax2.plot(range(len(YN)),KK[:,0],label='dT/d[$^{13}$C$^{16}$O]')
ax2.plot(range(len(YN)),KK[:,1],label='dT/d[$^{12}$C$^{18}$O]')
ax2.legend()

ax1.grid()
ax2.grid()
ax1.set_facecolor('lightgray')
ax2.set_facecolor('lightgray')

ax1.set_ylabel('Measurement vector')
ax1.set_xlabel('Measurement vector number (#)')

ax2.set_ylabel('Jacobian matrix (dY/dx)')
ax2.set_xlabel('Measurement vector number (#)')

plt.tight_layout()

# %% [markdown]
# ## 4. Calculating the spectral signature of each gas
#
# Similarly, we can run a modified version of the forward model to calculate the relative contribution of each gaseous species to the spectrum.
#
# Specifically, the *run_forward_model_gas_contributions()* method computes a forward model with each gaseous species independently.
#
# This is particularly useful in high-resolution spectroscopic observations, where we may want to see what gases correspond to individual absorption or emission lines.

# %%
SPECONV, SPECONV_gas = NEMESIS.run_forward_model_gas_contributions()
# Out:
# WARNING :: run_forward_model_gas_contributions :: Retrieval.py-1229 :: Retrieval(runname=mars_SO) already has a modelled spectra, running the forward model will overwrite the current value
# INFO :: nemesisSOfm :: ForwardModel_0.py-916 :: Calculating forward model for solar occultation observation
# INFO :: read_tables :: Spectroscopy_0.py-1461 :: Reading tables
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso1.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# INFO :: read_tables :: Spectroscopy_0.py-1518 :: Reading table self.LOCATION[igas]='../../../archnemesis/Data/reference_tables/lbltab_mars/lbltab_co_iso2.lta' wavemin=np.float64(4169.711730621892) wavemax=np.float64(4190.288269378108)
# ...

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3,1,figsize=(10,9))

igeom1 = NEMESIS.Measurement.NGEOM-5
igeom2 = 5
igeom3 = 2

labels = ['$^{12}$C$^{16}$O','$^{13}$C$^{16}$O','$^{12}$C$^{18}$O']

for iso in range(NEMESIS.Spectroscopy.NGAS):

    ax1.fill_between(NEMESIS.Measurement.VCONV[:,igeom1],SPECONV_gas[:,igeom1,iso],np.ones(NEMESIS.Measurement.NCONV[igeom1]),alpha=0.5)
    ax1.plot(NEMESIS.Measurement.VCONV[:,igeom1],SPECONV_gas[:,igeom1,iso],label=labels[iso])
    ax2.fill_between(NEMESIS.Measurement.VCONV[:,igeom2],SPECONV_gas[:,igeom2,iso],np.ones(NEMESIS.Measurement.NCONV[igeom1]),alpha=0.5)
    ax2.plot(NEMESIS.Measurement.VCONV[:,igeom2],SPECONV_gas[:,igeom2,iso],label=labels[iso])
    ax3.fill_between(NEMESIS.Measurement.VCONV[:,igeom3],SPECONV_gas[:,igeom3,iso],np.ones(NEMESIS.Measurement.NCONV[igeom1]),alpha=0.5)
    ax3.plot(NEMESIS.Measurement.VCONV[:,igeom3],SPECONV_gas[:,igeom3,iso],label=labels[iso])

offset= 0.0
ax1.plot(NEMESIS.Measurement.VCONV[:,igeom1],SPECONV[:,igeom1]+offset,c='black',label='Total')
ax2.plot(NEMESIS.Measurement.VCONV[:,igeom2],SPECONV[:,igeom2]+offset,c='black',label='Total')
ax3.plot(NEMESIS.Measurement.VCONV[:,igeom3],SPECONV[:,igeom3]+offset,c='black',label='Total')

ax1.legend()
ax1.set_facecolor('lightgray')
ax2.set_facecolor('lightgray')
ax3.set_facecolor('lightgray')
ax1.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom1,0])+' km')
ax2.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom2,0])+' km')
ax3.set_title('Tangent altitude = '+str(NEMESIS.Measurement.TANHE[igeom3,0])+' km')
ax1.set_ylabel('Transmission')
ax2.set_ylabel('Transmission')
ax3.set_ylabel('Transmission')
ax3.set_xlabel('Wavenumber (cm$^{-1}$)')
ax1.grid()
ax2.grid()
ax3.grid()
plt.tight_layout()
