# %%
from pathlib import Path

import h5py
from archnemesis.helpers import h5py_helper

from archnemesis.database.filetypes.ans_line_data_file import AnsLineDataFile
from archnemesis.database.filetypes.ans_partition_fn_data_file import AnsPartitionFunctionDataFile



RECREATE_TEST_FILES = True

test_data_dir = Path("./test_data")


original_source_file_lines = test_data_dir / "hitran24_lines.h5"
original_source_file_pf = test_data_dir / "hitran24_pf.h5"

# Copy data to new combined file
original_source_file = test_data_dir / "hitran24_combined.h5"
if original_source_file.exists():
	original_source_file.unlink()

with h5py.File(original_source_file, 'a') as g:
	with h5py.File(original_source_file_lines, 'r') as f:
		f.copy(f'/{AnsLineDataFile.target_group_name}', g)
		for grp in f["/sources"].values():
			h5py_helper.ensure_grp(g,grp.name)
			f.copy(grp[AnsLineDataFile.target_group_name].name, g[grp.name])
	with h5py.File(original_source_file_pf, 'r') as f:
		f.copy(f'/{AnsPartitionFunctionDataFile.target_group_name}', g)
		for grp in f["/sources"].values():
			h5py_helper.ensure_grp(g,grp.name)
			f.copy(grp[AnsPartitionFunctionDataFile.target_group_name].name, g[grp.name])

combined_external_source_file = original_source_file.with_stem(original_source_file.stem + '_with_external_sources')

test_file_subset_root = original_source_file.with_stem(original_source_file.stem + '_external_subset_root')
test_file_subset_source = original_source_file.with_stem(original_source_file.stem + '_external_subset_source')
test_file_subset_badname = original_source_file.with_stem(original_source_file.stem + '_external_subset_badname')


any_test_file_exists = False
for test_file in (combined_external_source_file, test_file_subset_root, test_file_subset_source, test_file_subset_badname):
	if test_file.exists():
		if RECREATE_TEST_FILES:
			test_file.unlink()
		else:
			print(f'Test file "{test_file}" exists, so will not create any test files')
			any_test_file_exists |= True


if any_test_file_exists:
	print('Will only create test files if no test files exist. Either delete them or set `RECREATE_TEST_FILES` to True')

else:

	# Choose molecules to add to test dataset
	mols_1 = ['CH4', 'H2O'] # add to `test_file_subset_root`
	mols_2 = ['H2S', 'CO', 'CO2'] # add as one source in `test_file_subset_source`
	mols_3 = ['H2', 'GeH4'] # add as another source in `test_file_subset_source`
	mols_4 = ['O2', 'O3'] #  add in `test_file_subset_badname`

	target_group_names = ('partition_function', 'line_data')
	#target_group_names = ('line_data',)

	for target_group_name in target_group_names:

		with h5py.File(original_source_file, 'r') as f:
			with h5py.File(test_file_subset_root, 'a') as g:
				xpf_grp = h5py_helper.ensure_grp(g, target_group_name)
				for mol in mols_1:
					f.copy(f'/sources/HITRAN24/{target_group_name}/{mol}', xpf_grp)
			
			with h5py.File(test_file_subset_source, 'a') as g:
				s_grp = h5py_helper.ensure_grp(g, 'sources')
				xs_grp_1 = h5py_helper.ensure_grp(s_grp, 'HITRAN24')
				pfxs_grp_1 = h5py_helper.ensure_grp(xs_grp_1, target_group_name)
				
				xs_grp_2 = h5py_helper.ensure_grp(s_grp, 'TEST_SOURCE')
				pfxs_grp_2 = h5py_helper.ensure_grp(xs_grp_2, target_group_name)
				
				for mol in mols_2:
					f.copy(f'/sources/HITRAN24/{target_group_name}/{mol}', pfxs_grp_1)
				
				for mol in mols_3:
					f.copy(f'/sources/HITRAN24/{target_group_name}/{mol}', pfxs_grp_2)
			
			with h5py.File(test_file_subset_badname, 'a') as g:
				xpf_grp = h5py_helper.ensure_grp(g, f'bad_name_{target_group_name}')
				for mol in mols_4:
					f.copy(f'/sources/HITRAN24/{target_group_name}/{mol}', xpf_grp)


		source_map = {
			'external_filename_only' : (test_file_subset_root,),
			'external_source_hitran24' : (test_file_subset_source, f'/sources/HITRAN24/{target_group_name}'),
			'external_source_test' : (str(test_file_subset_source), f'/sources/TEST_SOURCE/{target_group_name}'),
			'external_file_with_group' : (test_file_subset_badname, f'/bad_name_{target_group_name}'),
		}
		
		print(f'DEBUG : {target_group_name=}')
		
		if target_group_name == 'line_data':
			ld_file_with_external_sources = AnsLineDataFile(combined_external_source_file)
			for source_name, source_info in source_map.items():
				ld_file_with_external_sources.add_source_link(source_name, *source_info)
		
		elif target_group_name == 'partition_function':
			pf_file_with_external_sources = AnsPartitionFunctionDataFile(combined_external_source_file)
			for source_name, source_info in source_map.items():
				pf_file_with_external_sources.add_source_link(source_name, *source_info)
# Out:
# DEBUG : target_group_name='partition_function'
# INFO :: _validate_data_group :: ans_partition_fn_data_file.py-108 :: Validation for "/partition_function" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# INFO :: _validate_data_group :: ans_partition_fn_data_file.py-108 :: Validation for "/partition_function" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# INFO :: _validate_data_group :: ans_partition_fn_data_file.py-108 :: Validation for "/partition_function" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# INFO :: _validate_data_group :: ans_partition_fn_data_file.py-108 :: Validation for "/partition_function" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# DEBUG : target_group_name='line_data'
# WARNING : Source group '/sources/external_file_with_group' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# WARNING : Source group '/sources/external_source_hitran24' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# WARNING : Source group '/sources/external_source_test' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# mol_grp_name='CH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# INFO :: _validate_data_group :: ans_line_data_file.py-79 :: Validation for "/line_data" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# WARNING : Source group '/sources/external_file_with_group' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# WARNING : Source group '/sources/external_source_test' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# mol_grp_name='CH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='8'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='9'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# INFO :: _validate_data_group :: ans_line_data_file.py-79 :: Validation for "/line_data" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# WARNING : Source group '/sources/external_file_with_group' in 'test_data/hitran24_combined_with_external_sources.h5' should have a 'line_data' sub-group. This one has entries ('partition_function',), therefore not using as a source for '/line_data'.
# mol_grp_name='CH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='8'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='9'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# INFO :: _validate_data_group :: ans_line_data_file.py-79 :: Validation for "/line_data" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
# mol_grp_name='O2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O2' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O3' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O3' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O3' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O3' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='O3' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2O' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='6'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='7'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='8'
# leaf_grp_name='line_set_0000'
# mol_grp_name='CO2' iso_grp_name='9'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2S' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='3'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='4'
# leaf_grp_name='line_set_0000'
# mol_grp_name='GeH4' iso_grp_name='5'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2' iso_grp_name='1'
# leaf_grp_name='line_set_0000'
# mol_grp_name='H2' iso_grp_name='2'
# leaf_grp_name='line_set_0000'
# INFO :: _validate_data_group :: ans_line_data_file.py-79 :: Validation for "/line_data" in "test_data/hitran24_combined_with_external_sources.h5" succeeded
