# %%
# Download HITRAN24 data from web #

from pathlib import Path
import zipfile
from archnemesis.database.utils import fetch
from archnemesis.database.readers.hitran.isotopologues import download_hitran_isotope_data


HITRAN_DOWNLOAD_URL = "https://saco.csic.es/s/9y7LW4craTJARWR/download?path=%2F&files=HITRAN24&downloadStartSecret=anything_can_go_here"

test_data_dir = Path("./test_data")
hitran_zipfile_path = test_data_dir / "HITRAN24.zip"
hitran_archive_extract_path = test_data_dir
hitran_archive_path = test_data_dir / "HITRAN24"
ans_database_file = test_data_dir / "hitran24.h5"

test_data_dir.mkdir(parents=True, exist_ok=True)

if not hitran_zipfile_path.exists():
	hitran_databse = fetch.file(HITRAN_DOWNLOAD_URL, to_fpath = hitran_zipfile_path, chunk_size=10*1024*1024)

hitran_zipfile = zipfile.ZipFile(hitran_zipfile_path).extractall(hitran_archive_extract_path)



download_hitran_isotope_data(test_data_dir)

# A bit of fiddling to load the isotope data we just downloaded
import importlib
import sys

MODULE_PATH = test_data_dir / "isotope_data.py"
MODULE_NAME = "hitran_isotope_data"
spec = importlib.util.spec_from_file_location(MODULE_NAME, MODULE_PATH)
hitran_isotope_data = importlib.util.module_from_spec(spec)
sys.modules[spec.name] = hitran_isotope_data 
spec.loader.exec_module(hitran_isotope_data)

hitran_isotopes = hitran_isotope_data.HitranIsotope.dict()
# Out:
# INFO :: file_in_chunks :: fetch.py-45 :: url='https://hitran.org/docs/iso-meta/'
# INFO :: file_in_chunks :: fetch.py-100 :: Fetching chunk 0. Chunk is 83.0009765625 Kb. Fetched 0.0 Kb so far...
# INFO :: file_in_chunks :: fetch.py-107 :: Fetch complete, downloaded 83.0009765625 Kb in total over 1 chunks.
# MOL <h4>1: H<sub>2</sub>O</h4>
# h4.contents=['1: H', <sub>2</sub>, 'O']
# html_content_or_tag=['H', <sub>2</sub>, 'O']
# DEBUG : type(item)=<class 'str'> item='H'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>1</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>H<sub>2</sub><sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='H'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">161</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.97317 × 10<sup>-1</sup></td>
# items=['9.97317\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">18.010565</td>
# items=['18.010565']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.7458 × 10<sup>2</sup></td>
# items=['1.7458\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q1.txt">q1.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>2</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>H<sub>2</sub><sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='H'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">181</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.99983 × 10<sup>-3</sup></td>
# items=['1.99983\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">20.014811</td>
# items=['20.014811']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.7605 × 10<sup>2</sup></td>
# items=['1.7605\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q2.txt">q2.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>3</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>3</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>H<sub>2</sub><sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='H'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">171</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.71884 × 10<sup>-4</sup></td>
# items=['3.71884\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">19.014780</td>
# items=['19.014780']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.0521 × 10<sup>3</sup></td>
# items=['1.0521\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q3.txt">q3.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>4</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>4</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>HD<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='HD'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : within_iso_def=True expect='atom_count' D
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">162</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.10693 × 10<sup>-4</sup></td>
# items=['3.10693\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">19.016740</td>
# items=['19.016740']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">8.6474 × 10<sup>2</sup></td>
# items=['8.6474\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q4.txt">q4.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>5</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>5</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>HD<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='HD'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : within_iso_def=True expect='atom_count' D
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">182</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>6.23003 × 10<sup>-7</sup></td>
# items=['6.23003\xa0×\xa010', <sup>-7</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">21.020985</td>
# items=['21.020985']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">8.7557 × 10<sup>2</sup></td>
# items=['8.7557\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q5.txt">q5.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>6</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>6</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>HD<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='HD'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : within_iso_def=True expect='atom_count' D
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">172</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.15853 × 10<sup>-7</sup></td>
# items=['1.15853\xa0×\xa010', <sup>-7</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">20.020956</td>
# items=['20.020956']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">5.2268 × 10<sup>3</sup></td>
# items=['5.2268\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q6.txt">q6.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">36</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>129</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>7</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>D<sub>2</sub><sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='D'
# DEBUG : within_iso_def=False expect='nucleon_number' D
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">262</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>2.41974 × 10<sup>-8</sup></td>
# items=['2.41974\xa0×\xa010', <sup>-8</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">20.022915</td>
# items=['20.022915']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.0278 × 10<sup>3</sup></td>
# items=['1.0278\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q129.txt">q129.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# MOL <h4>2: CO<sub>2</sub></h4>
# h4.contents=['2: CO', <sub>2</sub>]
# html_content_or_tag=['CO', <sub>2</sub>]
# DEBUG : type(item)=<class 'str'> item='CO'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>7</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>16</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">626</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.84204 × 10<sup>-1</sup></td>
# items=['9.84204\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">43.989830</td>
# items=['43.989830']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">2.8609 × 10<sup>2</sup></td>
# items=['2.8609\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q7.txt">q7.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>8</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>16</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">636</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.10574 × 10<sup>-2</sup></td>
# items=['1.10574\xa0×\xa010', <sup>-2</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">44.993185</td>
# items=['44.993185']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">5.7664 × 10<sup>2</sup></td>
# items=['5.7664\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q8.txt">q8.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>9</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>3</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>12</sup>C<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">628</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.94707 × 10<sup>-3</sup></td>
# items=['3.94707\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">45.994076</td>
# items=['45.994076']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.0781 × 10<sup>2</sup></td>
# items=['6.0781\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q9.txt">q9.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>10</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>4</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>12</sup>C<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">627</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>7.33989 × 10<sup>-4</sup></td>
# items=['7.33989\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">44.994045</td>
# items=['44.994045']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.5426 × 10<sup>3</sup></td>
# items=['3.5426\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q10.txt">q10.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>11</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>5</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>13</sup>C<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">638</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>4.43446 × 10<sup>-5</sup></td>
# items=['4.43446\xa0×\xa010', <sup>-5</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">46.997431</td>
# items=['46.997431']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.2255 × 10<sup>3</sup></td>
# items=['1.2255\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q11.txt">q11.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>12</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>6</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>13</sup>C<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">637</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>8.24623 × 10<sup>-6</sup></td>
# items=['8.24623\xa0×\xa010', <sup>-6</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">45.997400</td>
# items=['45.997400']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">7.1413 × 10<sup>3</sup></td>
# items=['7.1413\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q12.txt">q12.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">12</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>13</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>7</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>18</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">828</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.95734 × 10<sup>-6</sup></td>
# items=['3.95734\xa0×\xa010', <sup>-6</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">47.998320</td>
# items=['47.998320']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.2342 × 10<sup>2</sup></td>
# items=['3.2342\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q13.txt">q13.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>14</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>8</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>17</sup>O<sup>12</sup>C<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">827</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.47180 × 10<sup>-6</sup></td>
# items=['1.47180\xa0×\xa010', <sup>-6</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">46.998291</td>
# items=['46.998291']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.7666 × 10<sup>3</sup></td>
# items=['3.7666\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q14.txt">q14.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>121</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>9</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>17</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">727</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.36847 × 10<sup>-7</sup></td>
# items=['1.36847\xa0×\xa010', <sup>-7</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">45.998262</td>
# items=['45.998262']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.0972 × 10<sup>4</sup></td>
# items=['1.0972\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q121.txt">q121.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>15</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>0</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>18</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">838</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>4.44600 × 10<sup>-8</sup></td>
# items=['4.44600\xa0×\xa010', <sup>-8</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">49.001675</td>
# items=['49.001675']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.5224 × 10<sup>2</sup></td>
# items=['6.5224\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q15.txt">q15.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>120</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>11</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>18</sup>O<sup>13</sup>C<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">837</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.65354 × 10<sup>-8</sup></td>
# items=['1.65354\xa0×\xa010', <sup>-8</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">48.001646</td>
# items=['48.001646']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">7.5950 × 10<sup>3</sup></td>
# items=['7.5950\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q120.txt">q120.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">12</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>122</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>12</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>17</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">737</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.53745 × 10<sup>-9</sup></td>
# items=['1.53745\xa0×\xa010', <sup>-9</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">47.001618</td>
# items=['47.001618']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">2.2120 × 10<sup>4</sup></td>
# items=['2.2120\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q122.txt">q122.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# MOL <h4>3: O<sub>3</sub></h4>
# h4.contents=['3: O', <sub>3</sub>]
# html_content_or_tag=['O', <sub>3</sub>]
# DEBUG : type(item)=<class 'str'> item='O'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>3</sub>
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>16</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sub>3</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>3</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">666</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.92901 × 10<sup>-1</sup></td>
# items=['9.92901\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">47.984745</td>
# items=['47.984745']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.4750 × 10<sup>3</sup></td>
# items=['3.4750\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q16.txt">q16.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>17</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>16</sup>O<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">668</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.98194 × 10<sup>-3</sup></td>
# items=['3.98194\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">49.988991</td>
# items=['49.988991']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">7.5846 × 10<sup>3</sup></td>
# items=['7.5846\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q17.txt">q17.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>18</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>3</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>18</sup>O<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">686</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.99097 × 10<sup>-3</sup></td>
# items=['1.99097\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">49.988991</td>
# items=['49.988991']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.7030 × 10<sup>3</sup></td>
# items=['3.7030\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q18.txt">q18.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>19</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>4</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>16</sup>O<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">667</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>7.40475 × 10<sup>-4</sup></td>
# items=['7.40475\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">48.988960</td>
# items=['48.988960']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">4.4044 × 10<sup>4</sup></td>
# items=['4.4044\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q19.txt">q19.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>20</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>5</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>16</sup>O<sup>17</sup>O<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">676</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.70237 × 10<sup>-4</sup></td>
# items=['3.70237\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">48.988960</td>
# items=['48.988960']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">2.1742 × 10<sup>4</sup></td>
# items=['2.1742\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q20.txt">q20.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# MOL <h4>4: N<sub>2</sub>O</h4>
# h4.contents=['4: N', <sub>2</sub>, 'O']
# html_content_or_tag=['N', <sub>2</sub>, 'O']
# DEBUG : type(item)=<class 'str'> item='N'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>21</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>14</sup>N<sub>2</sub><sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">446</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.90333 × 10<sup>-1</sup></td>
# items=['9.90333\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">44.001062</td>
# items=['44.001062']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">4.9849 × 10<sup>3</sup></td>
# items=['4.9849\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q21.txt">q21.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">9</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>22</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>14</sup>N<sup>15</sup>N<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>15</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">456</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.64093 × 10<sup>-3</sup></td>
# items=['3.64093\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">44.998096</td>
# items=['44.998096']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.3616 × 10<sup>3</sup></td>
# items=['3.3616\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q22.txt">q22.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>23</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>3</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>15</sup>N<sup>14</sup>N<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>15</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">546</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.64093 × 10<sup>-3</sup></td>
# items=['3.64093\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">44.998096</td>
# items=['44.998096']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.4580 × 10<sup>3</sup></td>
# items=['3.4580\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q23.txt">q23.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>24</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>4</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>14</sup>N<sub>2</sub><sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">448</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.98582 × 10<sup>-3</sup></td>
# items=['1.98582\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">46.005308</td>
# items=['46.005308']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">5.3135 × 10<sup>3</sup></td>
# items=['5.3135\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q24.txt">q24.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">9</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>25</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>5</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>14</sup>N<sub>2</sub><sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">447</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.69280 × 10<sup>-4</sup></td>
# items=['3.69280\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">45.005278</td>
# items=['45.005278']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">3.0966 × 10<sup>4</sup></td>
# items=['3.0966\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q25.txt">q25.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">54</td>
# MOL <h4>5: CO</h4>
# h4.contents=['5: CO']
# html_content_or_tag=['CO']
# DEBUG : type(item)=<class 'str'> item='CO'
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>26</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">26</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.86544 × 10<sup>-1</sup></td>
# items=['9.86544\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">27.994915</td>
# items=['27.994915']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.0742 × 10<sup>2</sup></td>
# items=['1.0742\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q26.txt">q26.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>27</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">36</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.10836 × 10<sup>-2</sup></td>
# items=['1.10836\xa0×\xa010', <sup>-2</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">28.998270</td>
# items=['28.998270']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">2.2469 × 10<sup>2</sup></td>
# items=['2.2469\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q27.txt">q27.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>28</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>3</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">28</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>1.97822 × 10<sup>-3</sup></td>
# items=['1.97822\xa0×\xa010', <sup>-3</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">29.999161</td>
# items=['29.999161']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.1277 × 10<sup>2</sup></td>
# items=['1.1277\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q28.txt">q28.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>29</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>4</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">27</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>3.67867 × 10<sup>-4</sup></td>
# items=['3.67867\xa0×\xa010', <sup>-4</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">28.999130</td>
# items=['28.999130']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.6117 × 10<sup>2</sup></td>
# items=['6.6117\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q29.txt">q29.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>30</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>5</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>18</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>18</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">38</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>2.22250 × 10<sup>-5</sup></td>
# items=['2.22250\xa0×\xa010', <sup>-5</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">31.002516</td>
# items=['31.002516']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">2.3644 × 10<sup>2</sup></td>
# items=['2.3644\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q30.txt">q30.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">2</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>31</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>6</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>13</sup>C<sup>17</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>13</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>17</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">37</td>
# ...
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>158</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>H<sub>3</sub><sup>+</sup></td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='H'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>3</sub>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>+</sup>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">111</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.99533 × 10<sup>-1</sup></td>
# items=['9.99533\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">3.023475</td>
# items=['3.023475']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">5.0355 × 10<sup>1</sup></td>
# items=['5.0355\xa0×\xa010', <sup>1</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q158.txt">q158.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# MOL <h4>57: CH<sub>3</sub></h4>
# h4.contents=['57: CH', <sub>3</sub>]
# html_content_or_tag=['CH', <sub>3</sub>]
# DEBUG : type(item)=<class 'str'> item='CH'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>3</sub>
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>159</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>CH<sub>3</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='CH'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : within_iso_def=True expect='atom_count' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>3</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">2111</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.88428 × 10<sup>-1</sup></td>
# items=['9.88428\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">15.023475</td>
# items=['15.023475']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.6867 × 10<sup>2</sup></td>
# items=['6.6867\xa0×\xa010', <sup>2</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q159.txt">q159.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# MOL <h4>58: S<sub>2</sub></h4>
# h4.contents=['58: S', <sub>2</sub>]
# html_content_or_tag=['S', <sub>2</sub>]
# DEBUG : type(item)=<class 'str'> item='S'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>152</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>32</sup>S<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>32</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='S'
# DEBUG : within_iso_def=True expect='atom_name' S
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">22</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.02842 × 10<sup>-1</sup></td>
# items=['9.02842\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">63.944140</td>
# items=['63.944140']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">1.0067 × 10<sup>3</sup></td>
# items=['1.0067\xa0×\xa010', <sup>3</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q152.txt">q152.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">1</td>
# MOL <h4>59: COFCl</h4>
# h4.contents=['59: COFCl']
# html_content_or_tag=['COFCl']
# DEBUG : type(item)=<class 'str'> item='COFCl'
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>153</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>16</sup>O<sup>19</sup>F<sup>35</sup>Cl</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>19</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='F'
# DEBUG : within_iso_def=True expect='atom_name' F
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>35</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='Cl'
# DEBUG : within_iso_def=True expect='atom_name' Cl
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">2695</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>7.47510 × 10<sup>-1</sup></td>
# items=['7.47510\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">81.962172</td>
# items=['81.962172']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.2094 × 10<sup>5</sup></td>
# items=['6.2094\xa0×\xa010', <sup>5</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q153.txt">q153.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">8</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>154</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>12</sup>C<sup>16</sup>O<sup>19</sup>F<sup>37</sup>Cl</td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>12</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='C'
# DEBUG : within_iso_def=True expect='atom_name' C
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>19</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='F'
# DEBUG : within_iso_def=True expect='atom_name' F
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>37</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='Cl'
# DEBUG : within_iso_def=True expect='atom_name' Cl
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">2697</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>2.39035 × 10<sup>-1</sup></td>
# items=['2.39035\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">83.959223</td>
# items=['83.959223']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">6.4040 × 10<sup>5</sup></td>
# items=['6.4040\xa0×\xa010', <sup>5</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q154.txt">q154.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">8</td>
# MOL <h4>60: HONO</h4>
# h4.contents=['60: HONO']
# html_content_or_tag=['HONO']
# DEBUG : type(item)=<class 'str'> item='HONO'
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>157</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td>H<sup>16</sup>O<sup>14</sup>N<sup>16</sup>O</td>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='H'
# DEBUG : within_iso_def=False expect='nucleon_number' H
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">1646</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>9.91461 × 10<sup>-1</sup></td>
# items=['9.91461\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">47.000729</td>
# items=['47.000729']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">8.5076 × 10<sup>4</sup></td>
# items=['8.5076\xa0×\xa010', <sup>4</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q157.txt">q157.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">6</td>
# MOL <h4>61: ClNO<sub>2</sub></h4>
# h4.contents=['61: ClNO', <sub>2</sub>]
# html_content_or_tag=['ClNO', <sub>2</sub>]
# DEBUG : type(item)=<class 'str'> item='ClNO'
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# ## ISO ##
# tag.text='global ID'
# k='global id' tag.text.lower()[:len(k)]='global id'
# tag.text='local ID'
# k='local id' tag.text.lower()[:len(k)]='local id'
# tag.text='Formula'
# k='formula' tag.text.lower()[:len(k)]='formula'
# tag.text='AFGL code'
# k='afgl code' tag.text.lower()[:len(k)]='afgl code'
# tag.text='Abundance'
# k='abundance' tag.text.lower()[:len(k)]='abundance'
# tag.text='Molar Mass /g·mol-1'
# k='molar mass' tag.text.lower()[:len(k)]='molar mass'
# tag.text='Q(296\xa0K)'
# k='q(296' tag.text.lower()[:len(k)]='q(296'
# tag.text='Q (full range)'
# k='q (full' tag.text.lower()[:len(k)]='q (full'
# tag.text='gi'
# k='gi' tag.text.lower()[:len(k)]='gi'
# {0: 'global_id', 1: 'iso_id', 2: 'isotopologue', 3: 'AFGL', 4: 'terrestrial_abundance', 5: 'mol_mass', 6: 'q_ref', 7: 'q_file', 8: 'gi'}
# i=0 field_idx_to_name[i]='global_id' tag=<td>155</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>1</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>35</sup>Cl<sup>14</sup>N<sup>16</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>35</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='Cl'
# DEBUG : within_iso_def=True expect='atom_name' Cl
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">5466</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>7.51352 × 10<sup>-1</sup></td>
# items=['7.51352\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">80.961757</td>
# items=['80.961757']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">4.7838 × 10<sup>5</sup></td>
# items=['4.7838\xa0×\xa010', <sup>5</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q155.txt">q155.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">12</td>
# i=0 field_idx_to_name[i]='global_id' tag=<td>156</td>
# i=1 field_idx_to_name[i]='iso_id' tag=<td>2</td>
# i=2 field_idx_to_name[i]='isotopologue' tag=<td><sup>37</sup>Cl<sup>14</sup>N<sup>16</sup>O<sub>2</sub></td>
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>37</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='Cl'
# DEBUG : within_iso_def=True expect='atom_name' Cl
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>14</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='N'
# DEBUG : within_iso_def=True expect='atom_name' N
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sup>16</sup>
# DEBUG : type(item)=<class 'bs4.element.NavigableString'> item='O'
# DEBUG : within_iso_def=True expect='atom_name' O
# DEBUG : type(item)=<class 'bs4.element.Tag'> item=<sub>2</sub>
# i=3 field_idx_to_name[i]='AFGL' tag=<td style="text-align: center;">7466</td>
# i=4 field_idx_to_name[i]='terrestrial_abundance' tag=<td>2.40264 × 10<sup>-1</sup></td>
# items=['2.40264\xa0×\xa010', <sup>-1</sup>]
# i=5 field_idx_to_name[i]='mol_mass' tag=<td style="text-align: center;">82.958808</td>
# items=['82.958808']
# i=6 field_idx_to_name[i]='q_ref' tag=<td style="text-align: right;">4.9380 × 10<sup>5</sup></td>
# items=['4.9380\xa0×\xa010', <sup>5</sup>]
# i=7 field_idx_to_name[i]='q_file' tag=<td><a href="/data/Q/q156.txt">q156.txt</a></td>
# i=8 field_idx_to_name[i]='gi' tag=<td style="text-align: right;">12</td>

# %%
# Read data from HITRAN archive #

# NOTE: Reading the data with HAPI uses up a lot of memory, I nearly max-out my 16 GB of RAM and 16 GB swap.

import hapi
import numpy as np
import h5py

from archnemesis.database.datatypes.hitran.gas_descriptor import HitranGasDescriptor
from archnemesis.database.datatypes.gas_descriptor import RadtranGasDescriptor



# NOTE: if we have already written an HDF5 file, use that instead as it is faster and uses less memory

FORCE_READ_FROM_DATABASE = False

def get_isotope_abundances(mol_id, ISO):
	iso_ids = sorted(iso for (m, iso) in ISO if m == mol_id)
	return [ISO[(mol_id, iso)][2] for iso in iso_ids]

if FORCE_READ_FROM_DATABASE or (not ans_database_file.exists()):
	table_name = 'hitran24'

	#Initialise the database
	hapi.db_begin(str(hitran_archive_path))


	#Reading all the data
	(
		mol_id,
		local_iso_id,
		nu,
		sw,
		a,
		gamma_air,
		gamma_self,
		elower,
		n_air,
		delta_air,
		gp,
		gpp
	) = hapi.getColumns(
		table_name,
		[
			'molec_id',
			'local_iso_id',
			'nu',
			'sw',
			'a',
			'gamma_air',
			'gamma_self',
			'elower',
			'n_air',
			'delta_air',
			'gp',
			'gpp'
		]
	)

	#Identifying unique species
	molec_id_uniq = np.unique(mol_id)
	print(f'{molec_id_uniq=}')

	rt_gas_descs = []
	rt_gas_desc = None
	mask = np.ones_like(mol_id, dtype=bool)
	local_iso_id_radtran = -1*np.ones_like(mol_id, dtype=int)
	mol_id_radtran= -1*np.ones_like(mol_id, dtype=int)

	# Adjust HITRAN data
	for mol_hitran in molec_id_uniq:
		print(f'Adjusting HITRAN data for {mol_hitran=}')
		
		#Getting the isotopic abundances 
		#isotopic_abundances = get_isotope_abundances(mol_hitran, hapi.ISO)

		#Identifying the isotopes in the database
		iso_id_uniq = np.unique(local_iso_id[mol_id==mol_hitran])

		#Removing the isotopic abundance effect in the line strengths
		
		
		for iso in iso_id_uniq:
			mask[...] = ((mol_id == mol_hitran) & (local_iso_id == iso))
			print(f'{iso=} {np.count_nonzero(mask)=}')
			
			#sw[mask] = sw[mask] / isotopic_abundances[iso-1]
			
			hitran_isotope = hitran_isotopes[(mol_hitran, iso)]
			sw[mask] = sw[mask] / hitran_isotope.abundance
			rt_gas_desc = HitranGasDescriptor(mol_hitran, iso, hitran_isotope.global_id).to_radtran()
			print(f'{rt_gas_desc=}')
			
			rt_gas_descs.append(rt_gas_desc)
			
			local_iso_id_radtran[mask] = rt_gas_desc.iso_id
			mol_id_radtran[mask] = rt_gas_desc.gas_id


	print(f'{len(rt_gas_descs)=}')
	print(f'{mol_id_radtran.shape=}')
	print(f'{np.count_nonzero(mol_id_radtran<0)=}')

else:
	print(f'Loading from {ans_database_file}')
	mol_id_radtran_list = []
	local_iso_id_radtran_list = []
	nu_list = []
	sw_list = []
	a_list = []
	elower_list = []
	gamma_self_list = []
	gamma_air_list = []
	n_air_list = []
	delta_air_list = []

	with h5py.File(ans_database_file, 'r') as f:
		ld_grp = f['sources/HITRAN24/line_data']
		for mol_grp in ld_grp.values():
			for iso_grp in mol_grp.values():
				mol_id_radtran_list.append(iso_grp['mol_id'][tuple()])
				local_iso_id_radtran_list.append(iso_grp['local_iso_id'][tuple()])
				nu_list.append(iso_grp['nu'][tuple()])
				sw_list.append(iso_grp['sw'][tuple()])
				a_list.append(iso_grp['a'][tuple()])
				elower_list.append(iso_grp['elower'][tuple()])
				gamma_self_list.append(iso_grp['gamma_self'][tuple()])
				
				if 'broadeners' in iso_grp:
					b_grp = iso_grp['broadeners']
					if 'AIR' in b_grp:
						amb_grp = b_grp['AIR']
						gamma_air_list.append(amb_grp['gamma_amb'][tuple()])
						n_air_list.append(amb_grp['n_amb'][tuple()])
						delta_air_list.append(amb_grp['delta_amb'][tuple()])
	
	mol_id_radtran =np.concatenate(mol_id_radtran_list)
	local_iso_id_radtran =np.concatenate(local_iso_id_radtran_list)
	nu =np.concatenate(nu_list)
	sw =np.concatenate(sw_list)
	a =np.concatenate(a_list)
	elower =np.concatenate(elower_list)
	gamma_self =np.concatenate(gamma_self_list)
	gamma_air =np.concatenate(gamma_air_list)
	n_air =np.concatenate(n_air_list)
	delta_air =np.concatenate(delta_air_list)
# Out:
# Loading from test_data/hitran24.h5

# %% [markdown]
# ## ARCHNEMESIS HDF5 "AnsDatabase" File Format ##
#
# As HDF5 files are very adaptable, the AnsDatabase format is just some conventions that certain groups should follow. There are three top-level groups `line_data`, `partition_function`, and `sources` that follow the specifications below.
#
# HDF5 files have "Virtual Datasets", these are datasets that can be built from other datasets in the same file or in different files. These are used to enable the `line_data` and `partition_function` groups to refer to data within the `sources` group and even to data in separate files. If a dataset in the top-level `line_data` or `partition_function` groups is not virtual, then it will not be overwritten when updating virtual datasets.
#
# NOTE: the HDF5 extension in VSCode does not deal with virtual datasets that reference separate files correctly. However, the example `ex_03_ans_hdf5_file_external_sources_example.ipynb` uses an AnsDatabase file that only contains virtual datasets that reference external files and it works fine.
#
# NOTE: Groups with a variable name are denoted as `<variable_name>`.
#
# ### The `line_data` Group ###
#
# Must contain sub-groups and datasets in the following structure, note that ordering is not important:
#
# * Group: `<mol_name>`
#   * Group: `<iso_id>`
#     * Dataset: `mol_id`
#     * Dataset: `local_iso_id`
#     * Dataset: `nu`
#     * Dataset: `sw`
#     * Dataset: `a`
#     * Dataset: `elower`
#     * Dataset: `gamma_self`
#     * Dataset: `n_self`
#     * Group: `broadeners`
#       * Group: `<ambient_gas>`
#         * Dataset: `gamma_amb`
#         * Dataset: `n_amb`
#         * Dataset: `delta_amb`
#
# All datasets must have the same number of entries in the first dimension, and currently all datasets are 1-dimensional. Values are associated by index, (i.e., `nu[0]` is the wavenumber corresponding to the line strength in `sw[0]`). It is the job of the person who creates the file to ensure that there is no missing data, and all data entries line up correctly.
#
# #### item descriptions ####
#
# * `<mol_name>` - String of molecule name, one group for each molecule
# * `<iso_id>` - String of radtran isotopologue ID number, one group for each isotopologue of a molecule
# * `mol_id` - Radtran molecule ID number
# * `local_iso_id` - Radtran isotopologue ID number (relative to molecule ID number)
# * `nu` - Wavenumber of line
# * `sw` - Spectral line intensity at T=296 Kelvin
# * `a` - Einstein A-coefficient
# * `elower` - Lower state energy of transition
# * `gamma_self` - Self-broadened HWHM at T=296 Kelvin
# * `n_self` - Temperature exponent for `gamma_self`
# * `broadeners` - Literal string "broadeners" that contains sub-groups for each ambient broadening gas
# * `<ambient_gas>` - String of ambient gas, one group for each broadening gas for the isotopologue.
# * `gamma_amb` - Ambient gas broadened HWHM at T=296 kelvin
# * `n_amb` - Temperature exponent for `gamma_amb`
# * `delta_amb` - Pressure shift induced by ambient gas, referred to p=1 atm
#
#
# ### The `partition_function` Group ###
#
# Must contain sub-groups and datasets in the following structure, note that ordering is not important:
#
# * Group: `<mol_name>`
#   * Group: `<iso_id>`
#     * Group: `pf_data_<pf_data_index>`
#       * Dataset: `domain`
#       * Dataset: `partition_function_type`
#       * **Type Dependent Datasets Explained Below**
#
#
# The different `patition_function_type` values are `TabulatedPFData`, `PolynomialPFData`. The structure of each type is:
#
# * `...`
#   * `...`
#     * Group: `pf_data_<pf_data_index>`
#       * Dataset: `domain`
#       * `patition_function_type` = `TabulatedPFData`
#       * Dataset: `q`
#       * Dataset: `temp`
#
# * `...`
#   * `...`
#     * Group: `pf_data_<pf_data_index>`
#       * Dataset: `domain`
#       * `patition_function_type` = `PolynomialPFData`
#       * Dataset: `coeffs`
#
# #### item descriptions ####
#
# * `<mol_name>` - String of molecule name, one group for each molecule
# * `<iso_id>` - String of radtran isotopologue ID number, one group for each isotopologue of a molecule
# * `pf_data_<pf_data_index>` - String that starts with "pf_data_" and ends with an integer `<pf_data_index>` that exists to separate different partition function datasets for each isotopologue. A given partition function dataset may overlap with other partition function datasets.
# * `domain` - Two floats that denote the temperature range (in Kelvin) that the partition function dataset is valid for, a `TabulatedPFData` dataset will have a domain equal to its range of temperatures, a `PolynomialPFData` dataset will have a domain of (0, inf) by default.
# * `partition_function_type` - A string that denotes what other datasets are in the group. Has possible values `TabulatedPFData` and `PolynomialPFData`
#
# * `TabulatedPFData` - Partition function is described as a table of temperature vs partition function value.
#   * `q` - Partition function value
#   * `temp` - Temperature in Kelvin
#
# * `PolynomialPFData` - Partition function is described by a polynomial with temperature (in Kelvin) as the variable.
#   * `coeffs` - The coefficients (in order of increasing powers) of the polynomial.
#
#
# ### The `sources` Group ###
#
# Contains sub-groups for each source of data that are combined together to create the top-level `line_data` and `partition_function` groups. The structure is:
#
# * Group: `<source_name>`
#   * Group or Dataset: `line_data`
#   * Group or Dataset: `partition_function`
#
# The `line_data` and/or `partition_function` items can either be **Groups** or **Datasets**.
#
# If they are **Groups** they should follow the same format as the top-level group of the same name (they can even contain virtual datasets, but nesting virtual datasets too much can be confusing).
#
# If they are **Datasets** they always refer to a group in an external file (which should have the same format as the top-level group of the same name), the dataset can either be a **scalar string**, or a **1-dimensional array** containing 2 strings. If a **scalar string**, the string is the name of an external file and the group referred to has the same name as the dataset. If a **1-dimensional array**, the first string is the name of an external file and the second string is the name of the group within that file.
#
# All referred to groups should have the same structure as the top-level group of the same name as the dataset.
#
# #### item descriptions ####
#
# * `<source_name>` - Name of the source that the data within this group comes from. Use attributes to add more information as needed (e.g. references etc.)
# * `line_data` - Either a group that contains line data from the named source, or a dataset that points to a group in an external file that contains line data from the named source.
# * `partition_function` - Either a group that contains partition function data from the named source, or a dataset that points to a group in an external file that contains partiton function data from the named source.

# %%
# Add HITRAN24 data to HDF5 file #

from archnemesis.enums import AmbientGas

from archnemesis.database.data_holders.line_broadener_holder import LineBroadenerHolder
from archnemesis.database.data_holders.line_data_holder import LineDataHolder
from archnemesis.database.data_holders.partition_function_data_holder import PartitionFunctionDataHolder
from archnemesis.database.datatypes.pf_data.tabulated_pf_data import TabulatedPFData
from archnemesis.database.datatypes.pf_data.polynomial_pf_data import PolynomialPFData

from archnemesis.database.filetypes.ans_line_data_file import AnsLineDataFile
from archnemesis.database.filetypes.ans_partition_fn_data_file import AnsPartitionFunctionDataFile


USE_POLYNOMIAL_PARTITION_DATA = False

mol_list = []
iso_list = []

unique_mol_iso_ids = np.unique(np.stack((mol_id_radtran, local_iso_id_radtran),axis=1), axis=0)

# Create variable to hold partition function data
pfdh = PartitionFunctionDataHolder(
	'HITRAN24',
	'Data in this group is taken from the HITRAN24 database',
)

# Loop over isotopologues and add their partition function data to the PartitionFunctionDataHolder instance
for mol_id_rt, iso_id_rt in unique_mol_iso_ids:
	gas_desc = RadtranGasDescriptor(mol_id_rt, iso_id_rt)
	try:
		ht_gas_desc = HitranGasDescriptor.from_radtran(gas_desc)
	except KeyError:
		continue
	
	try:
		temp = hapi.TIPS_2021_ISOT_HASH[(ht_gas_desc.gas_id,ht_gas_desc.iso_id)]
		q = hapi.TIPS_2021_ISOQ_HASH[(ht_gas_desc.gas_id,ht_gas_desc.iso_id)]
	except KeyError:
		continue
	
	mol_list.append(mol_id_rt)
	iso_list.append(iso_id_rt)
	
	if USE_POLYNOMIAL_PARTITION_DATA:
		pfdh.add(
			mol_id_rt,
			iso_id_rt,
			PolynomialPFData(
				*TabulatedPFData(
					temp,
					q
				).as_poly()
			)
		)
	else:
		pfdh.add(
			mol_id_rt,
			iso_id_rt,
			TabulatedPFData(
				temp,
				q
			)
		)


# Get an HDF5 file to save the parttion function data in
hitran_pf_data_file = AnsPartitionFunctionDataFile(ans_database_file)

# Add the data in `pdfh` to the HDF5 file, this makes virtual datasets in the `partition_function` top-level group that refer to the source
hitran_pf_data_file.set_source(pfdh)


# Create a variable that holds the line data
hitran_line_data_holder = LineDataHolder(
	"HITRAN24",
	'Data in this group is taken from the HITRAN24 database',
	mol_id_radtran,
	local_iso_id_radtran,
	nu,
	sw,
	a,
	elower,
	gamma_self,
	np.zeros_like(gamma_self),
	broadeners = [
		LineBroadenerHolder(
			AmbientGas.AIR.name,
			gamma_air,
			n_air,
			delta_air,
		),
	],
)

# Get an HDF5 file to save the parttion function data in
hitran_line_data_file = AnsLineDataFile(ans_database_file)

# Add the data in `hitran_line_data_holder` to the HDF5 file, this makes virtual datasets in the `line_data` top-level group that refer to the source
hitran_line_data_file.set_source(hitran_line_data_holder)
# Out:
# INFO :: validate_partition_function_group :: ans_partition_fn_data_file.py-148 :: Validation for "/partition_function" in "test_data/hitran24.h5" succeeded
# DEBUG : u_ids.shape=(2, 148)
# INFO :: validate_line_data_group :: ans_line_data_file.py-121 :: Validation for "/sources/HITRAN24/line_data" in "test_data/hitran24.h5" succeeded
# INFO :: validate_line_data_group :: ans_line_data_file.py-121 :: Validation for "/line_data" in "test_data/hitran24.h5" succeeded
