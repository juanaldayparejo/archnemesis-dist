# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import archnemesis as ans
from archnemesis.database.datatypes.wave_range import WaveRange


# Define files used later

test_data_dir = Path("./test_data")
original_source_file = test_data_dir / "hitran24_combined.h5"
combined_external_source_file = original_source_file.with_stem(original_source_file.stem + '_with_external_sources')

# %%
# Constants that define the data source and isotopologue we are using 

ANS_LINE_DATABASE_FILE = combined_external_source_file
ANS_PARTITION_FUNCTION_DATABASE_FILE = combined_external_source_file

gasID, isoID, ambient_gas = (
    ans.enums.Gas.CH4, 
    0,
    ans.enums.AmbientGas.AIR,
)
vmin, vmax = WaveRange(1.3, 3.5, ans.enums.WaveUnit.Wavelength_um).as_unit(ans.enums.WaveUnit.Wavenumber_cm).values()

print(f'{gasID=} {isoID=}')
print(f'{vmin=} {vmax=}')
# Out:
# gasID=<Gas.CH4: 6> isoID=0
# vmin=2857.1428571428573 vmax=7692.3076923076915

# %%
# Create a LineData_0 instance and load the data we need

line_data = ans.LineData_0(
	ID=gasID,
	ISO=isoID,
	ambient_gasses=ambient_gas,
	LINE_DATABASE = ANS_LINE_DATABASE_FILE,
	PARTITION_FUNCTION_DATABASE = ANS_PARTITION_FUNCTION_DATABASE_FILE,
)

# Loading the line data in our required spectral range
line_data.set_params(vmin=vmin,vmax=vmax).fetch_linedata()

# Loading the partition function data
line_data.fetch_partition_fn()
# Out:
# LineData_0::fetch_partition_fn()
# Actually getting the partition function
# AnsLineDataFile::get_data(...)
# AnsLineDataFile :: target_line_set_params=(-1, 296)
# AnsLineDataFile::get_data(...)
# AnsLineDataFile :: target_line_set_params=(-1, 296)
# AnsLineDataFile::get_data(...)
# AnsLineDataFile :: target_line_set_params=(-1, 296)
# WARNING :: get_data :: ans_line_data_file.py-553 :: Compatible group "/line_data/CH4/4/line_set_0000" found, but no lines selected by requested_wn_range=(2857.1428571428573, 7692.3076923076915). Therefore will return empty data.
# WARNING :: get_data :: ans_line_data_file.py-556 :: No compatible group found for target_line_set_params=(-1, 296). Therefore will return empty data.
# AnsLineDataFile::get_data(...)
# AnsLineDataFile :: target_line_set_params=(-1, 296)
# single_iso_line_set_data.nu=array([2857.171427, 2857.197491, 2857.223263, ..., 7692.1944  ,
#        7692.2343  , 7692.2761  ])
# single_iso_line_set_data.nu=array([2857.227213, 2857.251825, 2857.297041, ..., 7681.7689  ,
#        7682.1373  , 7686.5569  ])
# single_iso_line_set_data.nu=array([2857.18486 , 2857.185201, 2857.190624, ..., 6530.0691  ,
#        6530.0927  , 6530.1328  ])
# single_iso_line_set_data.nu=array([], dtype=float64)
# LineData_0::fetch_partition_fn()

# %%
# Calculate line strengths and plot them #

line_strengths = line_data.calculate_line_strength(t_calc=200, combined_output=True)

plt.plot(line_data.combined_line_data.NU, line_strengths)
plt.title(f'Line strength for ({line_data.ID}, {line_data.ISO})')
plt.xlabel('Wavenumber (cm^{-1})')
plt.ylabel('Line Strength (cm^{-1} / [molec cm^{-2}])')
plt.show()

# %%
# Define a set of wavelengts to calculate absorption coefficient at and then plot them #

waves = np.linspace(2800, 3200, 1000)
k_abs = line_data.calculate_monochromatic_absorption(waves, 200, 1)

plt.plot(waves, k_abs)
plt.title(f'Absorption Coefficient for ({line_data.ID}, {line_data.ISO})')
plt.xlabel('Wavenumber (cm^{-1})')
plt.ylabel('Absorption Coefficient (1 / [molec cm^{-2}])')
plt.show()
# Out:
# INFO :: add_monochromatic_absorption :: LineData_0.py-2057 :: i=0 iso_line_data._data.shape=(11, 165823) iso_continuum_data._data.shape=None
# INFO :: add_monochromatic_absorption :: LineData_0.py-2109 :: No continuum data
# INFO :: add_monochromatic_absorption :: LineData_0.py-2057 :: i=1 iso_line_data._data.shape=(11, 29720) iso_continuum_data._data.shape=None
# INFO :: add_monochromatic_absorption :: LineData_0.py-2109 :: No continuum data
# INFO :: add_monochromatic_absorption :: LineData_0.py-2057 :: i=2 iso_line_data._data.shape=(11, 35908) iso_continuum_data._data.shape=None
# INFO :: add_monochromatic_absorption :: LineData_0.py-2109 :: No continuum data
# INFO :: add_monochromatic_absorption :: LineData_0.py-2057 :: i=3 iso_line_data._data.shape=(11, 0) iso_continuum_data._data.shape=None
# INFO :: add_monochromatic_absorption :: LineData_0.py-2109 :: No continuum data

# %%
# Create example plot #

line_data.plot_linedata()
