# %% [markdown]
# # Introduction
#
# <div class="alert alert-info">
#
# Summary
#
# **Models** reduce the amount of **state** that has to be investigated by ArchNEMESIS by parameterising some elements of the **state**. The **model parameters** are varied and the **state** is updated to reflect the changes. ArchNEMESIS has a good number of **models** already, but new **models** (along with their parameterisations) are easily added allowing new methodologies for the analysis of planetary spectra.
#
# </div>
#
# At its core, ArchNEMESIS is a program that minimises the mis-match between **measured** spectra and **modelled** spectra. However, to get physically meaningful results the **modelled** spectra cannot freely vary, instead we impose conditions and contraints. One example of a constraint is ArchNEMESIS performs radiative transfer calculations with a specified **state** (e.g. gas spectra, aerosol refractive indicies, atmosphere setup) that **can** vary and compares the output of this **forward model** (the **modelled** spectra) to the **measured** spectra. Finding the **state** that makes the output of the **forward model** fit the **measured** spectrum the best is called **retrieving** that **state**, and the specific set of data and tools used is called the **retrieval**.
#
# The resources a **retrieval** requires to complete scales with the number of **state parameters** (the elements of the **state** that can be varied by ArchNEMESIS) that are used. Therefore **models** are used to parameterise some parts of the **state** and reduce the number of **state parameters** a **retrieval** requires.
#
# Examples of **models** include:
#
# - Modelling the *volume mixing ratio* of a gas as a gaussian around a mean pressure.
#
# - Modelling the *refractive index* of an aerosol as a power-law size distribution of particles that obey mie-scattering and rayleigh-scattering.
#
# - Modelling the *surface temperature* of a tidally-locked planet as a "hot" and "cold" hemisphere.
#
#
#
# ## Internal Details ##
#
# The **state** of a **retrieval** is spread across all of the **reference classes** that are used during one execution of ArchNEMESIS. For example, an `Atmosphere_0` instance holds part of the **state** that describes how the modelled atmosphere is split into layers, the pressure and temperature of those layers, and the gas and aerosol makeup of each layer.
#
# A **model** interacts with the **reference classes** to force some of the **state** held by the **reference classes** to behave according to the **model** and vary only by interacting with the **model parameters**. For example, `Model47` forces one of the aerosol density profiles held by an `Atmosphere_0` instance to be described by a gaussian, the mean pressure and the variance of the gaussian are the **parameters** of `Model47`.
#
# The **parameters** for all **models** being used during a **retrieval** are collectively called the **state parameters** (i.e. the **parameters** that define the **state**). ArchNEMESIS restricts all **state parameters** to always be *floating point* variables for technical reasons, the internal array that holds the **state parameters** is called the "state parameter vector" or **state vector**.
#
# The `Variables_0` class holds all data pertaining to the **state parameters** (e.g., the **state vector** along with other data such as if a value is represented as a logarithm or not), and therefore holds the **model** instances that are being used in a **retrieval**. `Variables_0` is also responsible for reading the `<runname>.apr` input file, which is the file that specifies which **models** are used and the *apriori* values of their **parameters**.
#
#
# ## The `<runname>.apr` File ##
#
# The `<runname>.apr` file tells ArchNEMESIS which **models** are used by the **retrieval**, the **parameters** of each **model**, and which part of the **state** the **model** parameterises (if a **model** could describe more than one part of the **state**). To do this, each **model** is given an `id` number (see later) and each entry in the `<runname>.apr` file starts with a `VARIDENT` line.
#
# A `VARIDENT` line is made up of three integers "I$_1$ I$_2$ I$_3$"
#
# - I$_1$ - If the **model** parameterises part of the atmospheric **state**, specifies which part of the atmospheric **state** is parameterised according to the bullets below, otherwise it is unused (but often set to the **model** `id` number).
#
#     - If I$_1$ = 0, then the model parameterisation applies to the *temperature* profile.
#
#     - If I$_1$ > 0, then the model parameterisation applies to a *gas volume mixing ratio*, with I$_1$ and I$_2$ representing the gas ID and isotope ID (e.g., I$_1$=1, I$_2$=0 for H$_2$O;  I$_1$=1, I$_2$=4 for HDO).
#
#     - If I$_1$ < 0, then we can have:
#
#         - If 1 $\leq$ |I$_1$| $\leq$ NDUST (the number of aerosol species present), then the model parameterises the *aerosol density* of the I$_1$ aerosol population.
#
#         - If |I$_1$| = NDUST + 1, then the model parameterisation applies to the *para-H*$_2$ *fraction* profile.
#
#         - If |I$_1$| = NDUST + 1, then the model parameterisation applies to the *fractional cloud cover* profile.
#
# - I$_2$ - If the **model** parameterises one of the *gas volume mixing ratios* of the atmospheric **state**, specifies the parameterised *gas isotope id*. Otherwise it is unused (often set to 0).
#
# - I$_3$ - Specifies the **model** `id` number
#
#
# <div class="alert alert-warning" >
#
# Examples of VARIDENT
#
# Let's assume we have an atmosphere with 3 aerosol populations. We include 5 model parameterisations, defined by:
#
# - `2 0 0` - Continuous vertical profile of CO$_2$ volume mixing ratio.
# - `-2 0 2` - Scaling factor for abundance of the second aerosol population in the atmosphere.
# - `-4 0 0` - Scaling factor for para-H2 fraction profile.
# - `-1 0 32` - Abundance of first aerosol population represented by base pressure, optical depth and fractional scale height.
# - `0 0 231` - Multiplication of spectrum by polynomial function
#
# </div>
#
#
# The lines following a `VARIDENT` are inputs to the specified **model**. Different **models** expect different input formats, the exact details are specified [later](#model-input-reference)

# %% [markdown]
# # Model Input Reference #
#
# The model parameterisations have the purpose of modifying the information in the reference classes according to a smaller number of parameters. This is especially important for retrievals, when these parameters are modified in each iteration to find the best fit between the modelled and measured spectra. Each of the model parameterisations is defined by some Variable IDs and Variable parameters, which are defined in the `<runname>.apr` file. This file can be read using the `Variable_0::read_apr(...)` method of the `Variables_0` class.
#
# You can run the command `python -c 'from archnemesis.Models import Models; print(Models.info())'` to display some summary information for each model.
#
# At this stage, only a number of models have been implemented in ArchNEMESIS with respect to NEMESIS. Detailed information about each of the model parameterisations is included in the Examples. In the following, a brief summary describing each of these models is included:

# %% [raw]
# <!-- Model 0 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 0: Continuous atmospheric vertical profile.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> NP</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li><b>Short description:</b> Specify the values of all vertical levels of the atmospheric profiles.</li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Number of vertical levels (NP) | Correlation length</li>
#         <li>Pressure (level 1) | Value (level 1) | Uncertainty (level 1)</li>
#         <li>...</li>
#         <li>Pressure (level NP) | Value (level NP) | Uncertainty (level NP)</li>
#       </ul>
#     </li>
#   </ul>
# </details>
# </div>

# %% [raw]
# <!-- Model 1 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 1: Variable deep abundance, fixed knee pressure and variable fractional scale height.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 2</li>
#     <li><b>No. of extra parameters:</b> 1</li>
#     <li><b>Short description:</b> In this model, an atmospheric vertical profiles (typically a gaseous abundance), is modelled by specifying a variable deep abundance, fixed knee pressure and variable fractional scale height.</li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Knee pressure</li>
#         <li>Deep abundance | Uncertainty</li>
#         <li>Fractional scale height | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 2 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 2: Scaling of an atmospheric vertical profile.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li><b>Short description:</b> Multiply vertical profile with a scaling factor.</li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Scaling factor | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 3 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 3: Scaling of an atmospheric vertical profile (carried in log-space).</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> Multiply vertical profile with a scaling factor. Internally within
#       the code this scaling factor is converted to log-space. This is suitable for quantities
#       that can vary over orders of magnitudes and that cannot go negative.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Scaling factor | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 4 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 4: Variable deep abundance, knee pressure and fractional scale height.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 2</li>
#     <li><b>No. of extra parameters:</b> 1</li>
#     <li><b>Short description:</b> In this model, an atmospheric vertical profiles (typically a gaseous abundance), is modelled by specifying a variable deep abundance, knee pressure and variable fractional scale height. This model is equivalent to Model 1, but here we can retrieve the knee pressure too.</li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Knee pressure | Uncertainty </li>
#         <li>Deep abundance | Uncertainty</li>
#         <li>Fractional scale height | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 9 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 9: Cloud represented by base height, optical depth and fractional scale height.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 3</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> The vertical distribution of the cloud is parameterised by its base altitude and a fractional scale height. The total vertically-integrated optical depth of the cloud is also specified.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Base altitude (km) | Uncertainty</li>
#         <li>Optical depth | Uncertainty</li>
#         <li>Fractional scale height (km) | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 20 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 20: Variable deep abundance and fractional scale height, and fixed knee pressure and tropospheric cut-off pressure.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 2</li>
#     <li><b>No. of extra parameters:</b> 1</li>
#     <li><b>Short description:</b> In this model, an atmospheric vertical profiles (typically a gaseous abundance), is modelled by specifying a variable deep abundance and variable fractional scale height, and a fixed knee pressure and tropospheric cut-off pressure. This model is equivalent to Model 1, but here we add the tropospheric cut-off too.</li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Knee pressure | Tropospheric cut-off pressure </li>
#         <li>Deep abundance | Uncertainty</li>
#         <li>Fractional scale height | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 32 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 32: Cloud represented by base pressure, optical depth and fractional scale height.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 3</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> The vertical distribution of the cloud is parameterised by its base pressure and a fractional scale height. Below the base altitude the cloud decreases exponentially with a fractional scale height of 1 km. The total vertically-integrated optical depth of the cloud is also specified.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Base pressure (atm) | Uncertainty</li>
#         <li>Optical depth | Uncertainty</li>
#         <li>Fractional scale height (km) | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 43 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 43: Temperature profile from double grey analytic formulation from Parmentier and Guillot (2014).</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 5</li>
#     <li><b>No. of extra parameters:</b> 4</li>
#     <li>
#       <b>Short description:</b> In this model, the temperature profile is parameterised using the double grey analytic formulation derived in <a href="https://doi.org/10.1051/0004-6361/201322342" target="_blank">Parmentier and Guillot (2014)</a>.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> &alpha; | Uncertainty in &alpha; </li>
#         <li> &beta; | Uncertainty in &beta;  </li>
#         <li> k<sub>ir</sub> | Uncertainty in k<sub>ir</sub>  </li>
#         <li> &gamma;<sub>1</sub> | Uncertainty in &gamma;<sub>1</sub>  </li>
#         <li> &gamma;<sub>2</sub> | Uncertainty in &gamma;<sub>2</sub>  </li>
#         <li> Star temperature (K) | Star radius (km) | Star-planet distance (km) | Temperature of planet interior (K)  </li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 45 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 45: Irwin Ice Giant CH4 model.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 3</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> The vertical distribution of methane is specified with a deep abundance, a relative humidity in the troposphere, and a stratospheric abundance.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> Deep VMR | Uncertainty</li>
#         <li> Relative Humidity | Uncertainty</li>
#         <li> Stratospheric VMR | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 47 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 47: Gaussian cloud profile.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 3</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> A cloud modelled with a gaussian opacity profile in log(pressure), with a specified integrated opacity, central pressure, and standard deviation.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> Integrated Opacity | Uncertainty</li>
#         <li> Mean Pressure | Uncertainty</li>
#         <li> Standard Deviation (units of log(pressure)) | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 51 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 51: Scaling of another profile.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> This is parameterisation 49 in NEMESIS. Sets a specified profile equal to a simple scaling of another profile. Useful for varying isotopic abundances of a gas.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> Gas ID to be scaled | Isotope ID to be scaled </li>
#         <li> Scaling Factor | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 110 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 110: Model for Venus cloud from Haus et al. (2016) with an altitude offset.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> In this model, the Venus cloud is made of four particle modes from a solution of H2SO4 and H2O. The vertical distribution of each mode is parameterised following <a href="https://doi.org/10.1016/j.icarus.2016.02.048" target="_blank">Haus et al. (2016)</a>. In this implementation, we describe the cloud as in the Haus model, but allow an altitude offset to retrieve the altitude of the cloud.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> Altitude offset (km) | Uncertainty in altitude offset (km) </li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 111 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 111: Model for Venus cloud from Haus et al. (2016) with an altitude offset and coupled SO2 volume mixing ratio profile.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 3</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> In this model, the Venus cloud is made of four particle modes from a solution of H2SO4 and H2O. The vertical distribution of each mode is parameterised following <a href="https://doi.org/10.1016/j.icarus.2016.02.048" target="_blank">Haus et al. (2016)</a>. In this implementation, we describe the cloud as in the Haus model, but allow an altitude offset to retrieve the altitude of the cloud. In addition, we also include a parameterisation for the volume mixing ratio profile of SO2 by indicating its value below and above the cloud. The mixing ratio is assumed to decrease exponentially within the cloud.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li> Altitude offset (km) | Uncertainty in altitude offset (km) </li>
#         <li> SO2 mixing ratio below the cloud | Uncertainty in SO2 mixing ratio below the cloud  </li>
#         <li> SO2 mixing ratio above the cloud | Uncertainty in SO2 mixing ratio above the cloud  </li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 229 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 229: Model for double-Gaussian instrument line shape for TGO/ACS (Alday et al. 2019).</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 7</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> In this model, the instrument lineshape is modelled using a varying double-Gaussian function across the wavelength range. This model was introduced to mimic the instrument lineshape from the ACS instrument aboard the ExoMars Trace Gas Orbiter, and is defined by seven parameters. The first three parameters (P1, P2, P3) indicate the relative offset of the main Gaussian with respect to the wavelengths of the first, mid and last bins in the spectral range (aiming to account for small deviations in the wavelength calibration), with the offset in the rest of the bins being calculated by linear interpolation. The fourth parameter (P4) indicates the relative offset of the second Gaussian with respect to the main one. The fifth parameter (P5) represents the full-width at half-maximum (FWHM) of the two Gaussians, which are assumed to have the same FWHM. The sixth and seventh parameters (P6, P7) indicate the relative amplitude of the second Gaussian with respect to the main one at the first and last bins of the wavelength array, being linearly interpolated for the rest of the bins.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>P1 | Uncertainty</li>
#         <li>P2 | Uncertainty</li>
#         <li>P3 | Uncertainty</li>
#         <li>P4 | Uncertainty</li>
#         <li>P5 | Uncertainty</li>
#         <li>P6 | Uncertainty</li>
#         <li>P7 | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 231 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 231: Multiplication of spectrum by polynomial function.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> NGEOM $\times$ (NDEGREE+1) </li>
#     <li><b>No. of extra parameters:</b> 2 (NGEOM and NDEGREE)</li>
#     <li>
#       <b>Short description:</b> In this model, we multiply each spectrum (NGEOM spectra) by a polynomial function of degree (NDEGREE). The polynomial function can be different for each of the spectra. The polynomial function is parameterised as $p(\lambda, \lambda_0) = A_0 + A_1(\lambda-\lambda_0) + A_2(\lambda-\lambda_0)^2 +$ ... $+ A_N(\lambda-\lambda_0)^N$, where $\lambda_0$ represents the first wavelength in the vector.
#     </li>
#     <li>
#       <b>Format in .apr file:</b> The next line in the file is a string containing the name of another file where this parametersiation is specified. The structure of the other file must follow:
#       <ul style="list-style-type: square;">
#         <li>NGEOM | NDEGREE</li>
#         <li>A0 (Geometry 1) | Uncertainty in A0 | A1 (Geometry 1) | Uncertainty in A1 | ... | AN (Geometry 1) | Uncertainty in AN </li>
#         <li>A0 (Geometry 2) | Uncertainty in A0 | A1 (Geometry 2) | Uncertainty in A1 | ... | AN (Geometry 2) | Uncertainty in AN </li>
#         <li>...</li>
#         <li>A0 (Geometry NGEOM) | Uncertainty in A0 | A1 (Geometry NGEOM) | Uncertainty in A1 | ... | AN (Geometry NGEOM) | Uncertainty in AN </li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 444 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 444: Size distribution and imaginary refractive index spectrum of aerosol species.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 2 + NWAVE </li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> This model is used to vary the size distribution and/or the imaginary refractive index spectrum of an aerosol species. Setting a negative correlation length sets the imaginary refractive index to be constant with wavelength.
#     </li>
#     <li>
#       <b>Format in .apr file:</b> The next line in the file is a string containing the name of another file where this parametersiation is specified. The structure of the other file must follow:
#       <ul style="list-style-type: square;">
#         <li> Mean size of species | Uncertainty </li>
#         <li> NWAVE (number of n_imag wavelengths) | Correlation length </li>
#         <li> Reference wavelength | Real refractive index at reference wavelength </li>
#         <li> Cross-section normalisation wavelength </li>
#         <li> Wavelength 1 | Imaginary refractive index 1 | Uncertainty </li>
#         <li> Wavelength 2 | Imaginary refractive index 2 | Uncertainty </li>
#         <li> ... | ... | ... </li>
#         <li> Wavelength NWAVE | Imaginary refractive index NWAVE | Uncertainty </li>
#
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 447 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 447: Specification of Doppler velocity.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> In this model, we specify the Doppler velocity between the target planet and the observer. Currently, the Doppler velocity is common for all geometries in the Measurement class, but in the future this will be updated for different Doppler velocities in different geometries, potentially enabling the retrieval of atmospheric winds.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Doppler velocity (km/s) | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 666 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 666: Retrieval of pressure at specified height.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 1</li>
#     <li>
#       <b>Short description:</b> In this model, the atmospheric pressure is specified at a given fixed tangent height (extra parameter). Then, the rest of the pressure levels will be adjusted based on the hydrostatic equilibrium relation (which depends on the temperature altitudinal profile).
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Tangent height (km)</li>
#         <li>Pressure (atm) | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 667 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 667: Scaling of spectrum by a dilution factor.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 1</li>
#     <li>
#       <b>Short description:</b> In this model, the computed spectrum is multiplied by a dilution factor (i.e., scaling factor). This modelled was initially introduced to account for strong temperature gradients in exoplanets, but it might be useful for other cases.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Dilution factor | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [raw]
# <!-- Model 999 -->
#
# <div style="margin-bottom: 0.5em;">
# <details>
#   <summary>Model 999: Retrieval of surface temperature.</summary>
#
#   <ul style="list-style-type: disc;">
#     <li><b>No. of parameters:</b> 1</li>
#     <li><b>No. of extra parameters:</b> 0</li>
#     <li>
#       <b>Short description:</b> In this model, the surface temperature (K) is modified.
#     </li>
#     <li>
#       <b>Format in .apr file:</b>
#       <ul style="list-style-type: square;">
#         <li>Surface temperature | Uncertainty</li>
#       </ul>
#     </li>
#   </ul>
#
# </details>
# </div>

# %% [markdown]
# | Model ID | No. of parameters | No. of extra parameters | Description |
# | --- | --- | --- | --- |
# | 49 | NP | 0 | Continuous atmospheric vertical profile in linear scale (i.e., allowing negative abundances) |
# | 50 | NP | 0 | Continuous profile of scaling factors in linear scale |
# | 2310 | NGEOM $\times$ (NDEGREE+1) $\times$ NWINDOWS | 3 | Same as model 231 but applying it to different spectral windows |

# %% [markdown]
# # Glossary #
#
# - **model** - A **parameterisation** of part of the **state** of a **retrieval**, a more accurate term in this context might be **state model**.
#
# - **model parameter** - A **parameter** of a **model**.
#
# - **parameterisation** - The act of describing a something (usually an array) in terms of a function and the **parameters** of that function.
#
# - **parameter** - An argument to a function, when that function controls another variable.
#
# - **retrieval** - The data and tools required to find what **state** best explains a **measured** spectra.
#
# - **state** - All data that is input to the radiative transfer calculations of ArchNEMESIS. An operational definition is that if two runs of ArchNEMESIS have the
# same **state**, they will always have the same output.
#
# - **state parameters** - The elements of the **state** that can be varied by ArchNEMESIS when fitting a **modelled** spectra to a **measured** spectra, often this
# is made up completely of **model parameters**.
#
# - **state vector** - The internal array that holds the current values of the **state parameters**
